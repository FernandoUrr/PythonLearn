# %% [markdown]
# Aquí se desarrollará todo lo concerniente al curso: Curso de Matemáticas para DS, Estadística Descriptiva.
#
# Recuerda los focos en los que nos vamos a especializar: Construcción de modelos y limpieza de datos.

# %%
# %pwd
# Out:
# 'c:\\Users\\furruchurtu\\OneDrive - LITOPLAS SA\\Documentos\\python'

# %%
import pandas as pd

# %% [markdown]
# Pandas sirve para leer toda la información, muestra todo como un tipo interesante.

# %%
df = pd.read_csv('cars.csv')
df
# Out:
#       manufacturer_name  model_name transmission   color  odometer_value  \
# 0                Subaru     Outback    automatic  silver          190000
# 1                Subaru     Outback    automatic    blue          290000
# 2                Subaru    Forester    automatic     red          402000
# 3                Subaru     Impreza   mechanical    blue           10000
# 4                Subaru      Legacy    automatic   black          280000
# ...                 ...         ...          ...     ...             ...
# 38526          Chrysler         300    automatic  silver          290000
# 38527          Chrysler  PT Cruiser   mechanical    blue          321000
# 38528          Chrysler         300    automatic    blue          777957
# 38529          Chrysler  PT Cruiser   mechanical   black           20000
# 38530          Chrysler     Voyager    automatic  silver          297729
#
#        year_produced engine_fuel  engine_has_gas engine_type  engine_capacity  \
# ...

# %%
df.dtypes
# Out:
# manufacturer_name     object
# model_name            object
# transmission          object
# color                 object
# odometer_value         int64
# year_produced          int64
# engine_fuel           object
# engine_has_gas          bool
# engine_type           object
# engine_capacity      float64
# body_type             object
# has_warranty            bool
# state                 object
# drivetrain            object
# price_usd            float64
# is_exchangeable         bool
# location_region       object
# number_of_photos       int64
# up_counter             int64
# feature_0               bool
# feature_1               bool
# feature_2               bool
# feature_3               bool
# feature_4               bool
# feature_5               bool
# feature_6               bool
# feature_7               bool
# feature_8               bool
# feature_9               bool
# duration_listed        int64
# dtype: object

# %% [markdown]
# Con la siguiente función se puede describir las principales estadísticas descriptivas. Es importante conocer

# %%
df.describe()
# Out:
#        odometer_value  year_produced  engine_capacity     price_usd  \
# count    38531.000000   38531.000000     38521.000000  38531.000000
# mean    248864.638447    2002.943734         2.055161   6639.971021
# std     136072.376530       8.065731         0.671178   6428.152018
# min          0.000000    1942.000000         0.200000      1.000000
# 25%     158000.000000    1998.000000         1.600000   2100.000000
# 50%     250000.000000    2003.000000         2.000000   4800.000000
# 75%     325000.000000    2009.000000         2.300000   8990.000000
# max    1000000.000000    2019.000000         8.000000  50000.000000
#
#        number_of_photos    up_counter  duration_listed
# count      38531.000000  38531.000000     38531.000000
# mean           9.649062     16.306091        80.577249
# std            6.093217     43.286933       112.826569
# min            1.000000      1.000000         0.000000
# 25%            5.000000      2.000000        23.000000
# ...

# %%
#Medidas  de tendencia central:
df['price_usd'].mean()
# Out:
# 6639.971021255613

# %%
df['price_usd'].median()
# Out:
# 4800.0

# %%
#Creando un histograma
df['price_usd'].plot.hist(bins = 50) #En este caso bins son los intervalos
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
import seaborn as sns

# %%
sns.displot(df, x = 'price_usd', hue = 'manufacturer_name')
#Hue: La columna que quiero que me haga las distribuciones

# %%
sns.displot(df, x = 'price_usd', hue = 'engine_type')

# %%
sns.displot(df, x = 'price_usd', hue = 'engine_type', multiple = 'stack')
#Con el parámetro de Multiple se pueden añadir en acumulado

# %%
#Aquí se pueden hacer unos groupby
df.groupby('engine_type').count()
# Out:
#              manufacturer_name  model_name  transmission  color  \
# engine_type
# diesel                   12874       12874         12874  12874
# electric                    10          10            10     10
# gasoline                 25647       25647         25647  25647
#
#              odometer_value  year_produced  engine_fuel  engine_has_gas  \
# engine_type
# diesel                12874          12874        12874           12874
# electric                 10             10           10              10
# gasoline              25647          25647        25647           25647
#
#              engine_capacity  body_type  ...  feature_1  feature_2  feature_3  \
# engine_type                              ...
# diesel                 12874      12874  ...      12874      12874      12874
# electric                   0         10  ...         10         10         10
# gasoline               25647      25647  ...      25647      25647      25647
#
# ...

# %%
#Hagamos ahora un histograma sencillo
Q7_df = df[(df['manufacturer_name'] == 'Audi') & (df['model_name'] == 'Q7')]
sns.histplot(Q7_df, x = 'price_usd', hue = 'year_produced')
# Out:
# <AxesSubplot:xlabel='price_usd', ylabel='Count'>

# %%
Nissan_df = df[(df['manufacturer_name'] == 'Nissan') & (df['model_name'] == 'Skyline')]
sns.histplot(Nissan_df, x = 'price_usd', hue = 'year_produced')
# Out:
# <AxesSubplot:xlabel='price_usd', ylabel='Count'>

# %%
#Medidas de dispersión
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Desviación estándar
df['price_usd'].std()
# Out:
# 6428.1520182029035

# %%
#Rango
rango = df['price_usd'].max() - df['price_usd'].min()
rango
# Out:
# 49999.0

# %%
#Quartiles
median = df['price_usd'].median()
Q1 = df['price_usd'].quantile(q = 0.25)
Q3 = df['price_usd'].quantile(q = 0.75)
min_val = df['price_usd'].quantile(q = 0)
max_val = df['price_usd'].quantile(q = 1)
print(min_val, Q1, median , Q3, max_val)
# Out:
# 1.0 2100.0 4800.0 8990.0 50000.0

# %%
iqr = Q3 - Q1
iqr
# Out:
# 6890.0

# %%
#Detección de los outliers
#Datos entre Q1 - 1.5*IQR y Q3 + 1.5*IQR
min_limit = Q1 - 1.5*iqr
if min_limit <= 0:
    min_limit = 0
max_limit = Q3 + 1.5*iqr
print(f'The outliers are less than {min_limit} and more than {max_limit}')
# Out:
# The outliers are less than 0 and more than 19325.0

# %%
sns.histplot(df['price_usd'])
# Out:
# <AxesSubplot:xlabel='price_usd', ylabel='Count'>

# %%
sns.boxplot(x = df['price_usd'])
# Out:
# <AxesSubplot:xlabel='price_usd'>

# %%
fig = plt.figure()
fig.add_subplot(1, 3, 2)
sns.boxplot(x = df['price_usd'])
fig. add_subplot(1, 3, 1)
sns.histplot(df['price_usd'])
# Out:
# <AxesSubplot:xlabel='price_usd', ylabel='Count'>

# %%
sns.boxplot(x = 'engine_fuel', y = 'price_usd', data = df)
# Out:
# <AxesSubplot:xlabel='engine_fuel', ylabel='price_usd'>

# %%
#Ahora vamos con los sccaterplots para revisión.
#Aquí cargamos el dataset de iris de sns
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.scatterplot(data = iris, x='sepal_length', y='petal_length', hue='species')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
#Join plot:
sns.jointplot(data = iris, x='sepal_length', y='petal_length', hue='species')

# %%
#Veamos si con matplotlib me deja configurar esto para visualizar en grid
sns.jointplot(data = iris, x='sepal_length', y='petal_length', hue='species')

# %%
#Boxplot
sns.boxplot(data=iris, x='species', y='petal_width')
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_width'>

# %%
#Haciendo el barplot
setosa = iris[iris['species'] == 'setosa']
sns.barplot(data = iris, x = 'species', y = 'petal_width')
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_width'>

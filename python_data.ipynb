# %%
# %pwd
# Out:
# 'c:\\Users\\furruchurtu\\OneDrive - LITOPLAS SA\\Documentos\\python'

# %%
import datetime

# %%
def add_numbers(a,b):
    """
    Add two numbers together
    Returns
    -----
    the_sum: Type of arguments

    """
    return a+b

# %%
path = %pwd

# %% [markdown]
# path

# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.plot(np.random.randn(50).cumsum())

# %%
a = 'foo'

# %%
import numpy as np
my_arr = np.arange(10000000)
my_list = list(range(10000000))

# %%
# %time for _ in range(10): my_arr2 = my_arr * 2
# Out:
# Wall time: 195 ms

# %%
# %time for _ in range(10): my_list2 = [x*2 for x in my_list]
# Out:
# Wall time: 7.84 s

# %%
data = np.random.randn(2, 3)
data
# Out:
# array([[ 0.41921022, -0.57760118, -0.46209671],
#        [-0.28466403, -0.05826795,  0.88535386]])

# %%
data*10
# Out:
# array([[ 4.19210219, -5.77601183, -4.62096713],
#        [-2.84664026, -0.58267949,  8.8535386 ]])

# %%
data.shape
# Out:
# (2, 3)

# %%
points = np.arange(-5, 5, 0.01) #1000 equally spaced points
xs, ys = np.meshgrid(points, points)

# %%
ys
# Out:
# array([[-5.  , -5.  , -5.  , ..., -5.  , -5.  , -5.  ],
#        [-4.99, -4.99, -4.99, ..., -4.99, -4.99, -4.99],
#        [-4.98, -4.98, -4.98, ..., -4.98, -4.98, -4.98],
#        ...,
#        [ 4.97,  4.97,  4.97, ...,  4.97,  4.97,  4.97],
#        [ 4.98,  4.98,  4.98, ...,  4.98,  4.98,  4.98],
#        [ 4.99,  4.99,  4.99, ...,  4.99,  4.99,  4.99]])

# %%
z = np.sqrt(xs**2+ys**2)
z
# Out:
# array([[7.07106781, 7.06400028, 7.05693985, ..., 7.04988652, 7.05693985,
#         7.06400028],
#        [7.06400028, 7.05692568, 7.04985815, ..., 7.04279774, 7.04985815,
#         7.05692568],
#        [7.05693985, 7.04985815, 7.04278354, ..., 7.03571603, 7.04278354,
#         7.04985815],
#        ...,
#        [7.04988652, 7.04279774, 7.03571603, ..., 7.0286414 , 7.03571603,
#         7.04279774],
#        [7.05693985, 7.04985815, 7.04278354, ..., 7.03571603, 7.04278354,
#         7.04985815],
#        [7.06400028, 7.05692568, 7.04985815, ..., 7.04279774, 7.04985815,
#         7.05692568]])

# %%
import matplotlib.pyplot as plt
plt.imshow(z, cmap=plt.cm.Blues); plt.colorbar()

# %%
import pandas as pd 
from pandas import Series
from pandas import DataFrame as df

# %%
data = {'state': ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada', 'Nevada'],
 'year': [2000, 2001, 2002, 2001, 2002, 2003],
 'pop': [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]}

frame = df(data)
frame
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2
